# %% [markdown]
# Notebook relativo a la parte A: <a href="https://colab.research.google.com/github/solracmendo/RL_MLSG/blob/main/MonteCarloCompleto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Notebook relativo a la parte B: <a href="https://colab.research.google.com/github/solracmendo/RL_MLSG/blob/main/EstudioAlgoritmos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
